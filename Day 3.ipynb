# %% [markdown]
# ```
# The submarine has been making some odd creaking noises, so you ask it to produce a diagnostic report just in case.
#
# The diagnostic report (your puzzle input) consists of a list of binary numbers which, when decoded properly, can tell you many useful things about the conditions of the submarine. The first parameter to check is the power consumption.
#
# You need to use the binary numbers in the diagnostic report to generate two new binary numbers (called the gamma rate and the epsilon rate). The power consumption can then be found by multiplying the gamma rate by the epsilon rate.
#
# Each bit in the gamma rate can be determined by finding the most common bit in the corresponding position of all numbers in the diagnostic report. For example, given the following diagnostic report:
#
# 00100
# 11110
# 10110
# 10111
# 10101
# 01111
# 00111
# 11100
# 10000
# 11001
# 00010
# 01010
#
# Considering only the first bit of each number, there are five 0 bits and seven 1 bits. Since the most common bit is 1, the first bit of the gamma rate is 1.
#
# The most common second bit of the numbers in the diagnostic report is 0, so the second bit of the gamma rate is 0.
#
# The most common value of the third, fourth, and fifth bits are 1, 1, and 0, respectively, and so the final three bits of the gamma rate are 110.
#
# So, the gamma rate is the binary number 10110, or 22 in decimal.
#
# The epsilon rate is calculated in a similar way; rather than use the most common bit, the least common bit from each position is used. So, the epsilon rate is 01001, or 9 in decimal. Multiplying the gamma rate (22) by the epsilon rate (9) produces the power consumption, 198.
#
# Use the binary numbers in your diagnostic report to calculate the gamma rate and epsilon rate, then multiply them together. What is the power consumption of the submarine? (Be sure to represent your answer in decimal, not binary.)
# ```

# %%
with open('day3_input.txt') as f:
    lines = f.read()

# %%
print(lines)
# Out:
# 100000101101
# 011011010101
# 000000111000
# 110101110111
# 110000001100
# 010111000011
# 100010110010
# 010010011011
# 111011100010
# 010100010001
# 100000010011
# 100000111100
# 101110000100
# 100000001000
# 001111100101
# 001000000010
# 101001110010
# 010111011111
# 110110111000
# 111100110001
# 011010110111
# 101111101000
# 101000000001
# 100111100101
# 101000001101
# 100111010110
# 110011101111
# 110111011111
# 010000111000
# 000001100001
# 010011101111
# 100011001101
# 000011000101
# 111110101001
# 001011000111
# 110101111010
# 101011000100
# 110000101110
# 101001110110
# 101001100010
# 010100110101
# 110011110011
# 100101010010
# 110100111011
# 010111010101
# 010111101011
# 110000100011
# 111011000101
# 110111000100
# 001110111101
# 011000011001
# 010111111110
# 110111010110
# 111111101001
# 001110001011
# 011001010001
# 110001000101
# 100010010000
# 101101011100
# 000101010000
# 011010001001
# 001100001000
# 001111101011
# 000100010101
# 001111001100
# 100010001110
# ...

# %%
test_input='''00100
11110
10110
10111
10101
01111
00111
11100
10000
11001
00010
01010'''

# %%
test_parse=test_input.splitlines()

# %%
test_parse
# Out:
# ['00100',
#  '11110',
#  '10110',
#  '10111',
#  '10101',
#  '01111',
#  '00111',
#  '11100',
#  '10000',
#  '11001',
#  '00010',
#  '01010']

# %%
len(test_parse[1])
# Out:
# 5

# %%
test_parse[1][0]
# Out:
# '1'

# %%
one_count=0
zero_count=0
column_total=[]
gamma_rate=''
epsilon_rate=''
for j in range(0, len(test_parse[i])):
    zero_count=0
    count=0
    for i in range(0, len(test_parse)):
#         print(test_parse[i])
#         print(test_parse[i][j])
        count+=int(test_parse[i][j])
        if int(test_parse[i][j]) == 0:
            zero_count+=1
               
    
    print(f'Hello, it is {j} column')
    print(f'1 count is {count}, zero count is {zero_count} ')
    if count> zero_count:
        print(f'{count} greater than {zero_count} ')
        #mst common
        gamma_rate+='1'
        #least commn
        epsilon_rate+='0'
    else:
        print(f'{count} less than or equal {zero_count} ')
        gamma_rate+='0'
        #least commn
        epsilon_rate+='1'
        
     
#     for j in range(0, len(test_parse[i])):
#         print(test_parse[i][1])
print(gamma_rate)
print(epsilon_rate)
# Out:
# Hello, it is 0 column
# 1 count is 7, zero count is 5
# 7 greater than 5
# Hello, it is 1 column
# 1 count is 5, zero count is 7
# 5 less than or equal 7
# Hello, it is 2 column
# 1 count is 8, zero count is 4
# 8 greater than 4
# Hello, it is 3 column
# 1 count is 7, zero count is 5
# 7 greater than 5
# Hello, it is 4 column
# 1 count is 5, zero count is 7
# 5 less than or equal 7
# 10110
# 01001

# %%
int(epsilon_rate, 2)
# Out:
# 9

# %%
int(gamma_rate, 2)
# Out:
# 22

# %%
one_count=0
zero_count=0
column_total=[]
gamma_rate=''
epsilon_rate=''
#lines
final_parse=lines.splitlines()
for j in range(0, len(final_parse[i])):
    zero_count=0
    count=0
    for i in range(0, len(final_parse)):
        print(test_parse[i])
        print(test_parse[i][j])
        count+=int(final_parse[i][j])
        if int(final_parse[i][j]) == 0:
            zero_count+=1
               
    
    print(f'Hello, it is {j} column')
    print(f'1 count is {count}, zero count is {zero_count} ')
    if count> zero_count:
        print(f'{count} greater than {zero_count} ')
        #mst common
        gamma_rate+='1'
        #least commn
        epsilon_rate+='0'
    else:
        print(f'{count} less than or equal {zero_count} ')
        gamma_rate+='0'
        #least commn
        epsilon_rate+='1'
        
     
#     for j in range(0, len(test_parse[i])):
#         print(test_parse[i][1])
print(gamma_rate)
print(epsilon_rate)
# Out:
# Hello, it is 0 column
# 1 count is 493, zero count is 507
# 493 less than or equal 507
# Hello, it is 1 column
# 1 count is 509, zero count is 491
# 509 greater than 491
# Hello, it is 2 column
# 1 count is 487, zero count is 513
# 487 less than or equal 513
# Hello, it is 3 column
# 1 count is 505, zero count is 495
# 505 greater than 495
# Hello, it is 4 column
# 1 count is 493, zero count is 507
# 493 less than or equal 507
# Hello, it is 5 column
# 1 count is 459, zero count is 541
# 459 less than or equal 541
# Hello, it is 6 column
# 1 count is 508, zero count is 492
# 508 greater than 492
# Hello, it is 7 column
# 1 count is 517, zero count is 483
# 517 greater than 483
# Hello, it is 8 column
# 1 count is 503, zero count is 497
# 503 greater than 497
# Hello, it is 9 column
# 1 count is 497, zero count is 503
# 497 less than or equal 503
# Hello, it is 10 column
# 1 count is 483, zero count is 517
# 483 less than or equal 517
# Hello, it is 11 column
# ...

# %%
int(epsilon_rate, 2)
# Out:
# 2758

# %%
int(gamma_rate, 2)
# Out:
# 1337

# %%
1337*2758
# Out:
# 3687446

# %% [markdown]
# ## Part 2

# %% [markdown]
# noo...
